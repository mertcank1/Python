# %%
sayı = int(input("bir sayı giriniz "))
if(sayı==0): print("sayı sıfır olamaz. ")
elif(sayı%7==0 and sayı%5==0):print(sayı," sayısı 7 ve 5 e tam bölünür")
elif(sayı%7==0): print(sayı," sayısı 7 ye tam bölünür. ")
elif(sayı%5==0): print(sayı," sayısı 5 e tam bölünür. ")
else:print(sayı," sayı 7 veya 5 e tam bölünemez. ")

# %%
import random
sayı = random.randint(1,9)
tahmin = int(input("1 ile 9 arasında bir sayı tahmin ediniz. "))
if(tahmin == sayı ): print("iyi tahmin. Sayı = ",sayı," Tahmin = ",tahmin)
else:print("yanlış tahmin sayı = ",sayı," Tahmin = ",tahmin)

# %%
kelime = str(input("Bir kelime giriniz. "))
if(kelime[0] == kelime[-1]): print("kelimenizin ilk ve son harfi aynı! Kelime = ",kelime," İlk ve Son Harf = ",kelime[0])
else:print("kelimenizin ilk ve son harfi aynı değil! Kelime = ",kelime," İlk Harfi = ",kelime[0]," Son Harfi = ",kelime[-1])

# %%
Boycm = int(input("Boyunuzu giriniz. "))
Kilo = int(input("Kilonuzu giriniz. "))
Boy = Boycm/100
bmi = (Kilo/(Boy**2))
if(bmi>=30):print("Obez sınıfındasınız. VKİ = ",bmi)
elif(25<=bmi<30):print("Aşırı kilolu sınıfındasınız. VKİ = ",bmi)
elif(20<=bmi<25):print("Normal kilo sınıfındasınız. VKİ = ",bmi)
elif(bmi<20):print("Zayıf kilo sınıfındasınız. VKİ = ",bmi)
