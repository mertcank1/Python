# %%
celcius_derece = 400 - 273.15 #çevirme

print(f"400 kelvin, {celcius_derece:.2f} celcius'dur")

# %%
pi = 3.14
yaricap = 1.5
#alan hesaplama
alan = pi * yaricap**2
#cevre hesaplama
cevre = 2 * pi * yaricap

print(f"Yarıcapı {yaricap}cm olan dairenin alanı : {alan:.2f} cm²")
print(f"Yarıcapı {yaricap}cm olan dairenin çevresi : {cevre:.2f} cm²")

# %%
#kullanıcıdan sayı alınır
sayi = int(input("dört basamaklı bir sayı girin:"))

#sayının ilk basamağınu bulma
ilk_basamak = sayi // 1000

#son basamağı bulma
son_basamak = sayi % 10

#ilk ve son basamaktaki sayinın toplamını bulma
toplam = ilk_basamak+son_basamak


print(f"Girilen sayının ilk basamağı:{ilk_basamak}")
print(f"Girilen sayının son basamağı:{son_basamak}")
print(f"Girilen sayının ilk ve son basamağının toplamı:{toplam}")

# %%
hız = 110
mesafe = 500
#Saat hesaplama
saat = mesafe/hız
#tam saat hesaplama
tam_saat =int(saat)
#dakika kısmı hesaplama
saat_dakika = (saat - tam_saat) * 60

print(f"Yolculuk {tam_saat} saat {saat_dakika:.2f} dakika sürer")
